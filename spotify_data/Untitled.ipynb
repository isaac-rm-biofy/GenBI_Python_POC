# %%
import pandas as pd

# %%
data_tracks = pd.read_csv('data_tracks_preprocessed.csv')
data_tracks.head()
# Out:
#                        id                       name artists  duration_ms  \
# 0  0gNNToCW3qjabgTyBSjt3H  !Que Vida! - Mono Version    Love       220560
# 1  0tMgFpOrXZR6irEOLNWwJL                       "40"      U2       157840
# 2  2ZywW3VyVx6rrlrX75n3JB                "40" - Live      U2       226200
# 3  6DdWA7D1o5TU2kXWyCLcch     "40" - Remastered 2008      U2       157667
# 4  3vMmwsAiLDCfyc1jl76lQE     "40" - Remastered 2008      U2       157667
#
#    year  acousticness  danceability  energy  instrumentalness  liveness  \
# 0  1966        0.5250         0.600   0.540           0.00305     0.100
# 1  1983        0.2280         0.368   0.480           0.70700     0.159
# 2  1983        0.0998         0.272   0.684           0.01450     0.946
# 3  1983        0.1850         0.371   0.545           0.58200     0.183
# 4  1983        0.1850         0.371   0.545           0.58200     0.183
#
#    loudness  speechiness    tempo  valence  mode  key  popularity  explicit
# ...

# %%
data_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169907 entries, 0 to 169906
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                169907 non-null  object
#  1   name              169907 non-null  object
#  2   artists           169907 non-null  object
#  3   duration_ms       169907 non-null  int64
#  4   year              169907 non-null  int64
#  5   acousticness      169907 non-null  float64
#  6   danceability      169907 non-null  float64
#  7   energy            169907 non-null  float64
#  8   instrumentalness  169907 non-null  float64
#  9   liveness          169907 non-null  float64
#  10  loudness          169907 non-null  float64
#  11  speechiness       169907 non-null  float64
#  12  tempo             169907 non-null  float64
#  13  valence           169907 non-null  float64
#  14  mode              169907 non-null  int64
# ...
